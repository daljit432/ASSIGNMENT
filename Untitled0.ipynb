# %% [markdown]
# <a href="https://colab.research.google.com/github/daljit432/ASSIGNMENT/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("hii, what's is your name?")
print("nice too meet you" + "nikita")
age = ("how old are you")
print("so, you are already" + str(24) + "years old," + name + "!")
# Out:
# hii, what's is your name?daljit
# nice too meet younikita
# so, you are already24years old,daljit!

# %%
print('hello world')

message = 'hellow world'# storing value in varible
print('hello world')
print(message)

message = """hellow' world how are you"""
print(message)
print(len(message)) # coutnt the worlds used in it 
print(message[5:])

#slicing 
message = 'hello world'

print(message.lower())
print(message.upper())
print(message.count('hello'))
print(message.count('l'))
print(message.count('universe'))

message = 'hello world'

new_message = message.replace('world', 'universe')

print(new_message)

greeting = 'hello'
name = 'nikita'

message = greeting + ', ' + name + ',sakshi!'

message = f'(geeting), (name.upper()), welcome!'

print(message)

greeting = 'hello'
name = 'daljit'

print(dir(name))
print(help(str))
print(help(str.upper))
# Out:
# hello world
# hello world
# hellow world
# hellow' world how are you
# 25
# w' world how are you
# hello world
# HELLO WORLD
# 1
# 3
# 0
# hello universe
# (geeting), (name.upper()), welcome!
# ...

# %%
# numeric data 

num = 3
 
print(num)
print(3-2)
print(5-6)
print(1+3)
print(5*5)
print(4/2)
print(3//2)

# exponents and power

print(3**2)
print(3%2)
print(3%2)
print(6%2)
print(3%2)
print(1%2)

print(3+2*2)
print(3*(1+2))

num = 1

num *= 10
 
print(num)
# Out:
# 3
# 1
# -1
# 4
# 25
# 2.0
# 1
# 9
# 1
# 1
# 0
# 1
# 1
# 7
# 9
# 10

# %%
print(abs(-1))
print(round(3.87))
print(round(3.87, 1))

num_1 = 3
num_2 = 5

print(num_1 == num_2)
print(num_1 != num_2)
print(num_1 < num_2)
print(num_1 > num_2)
print(num_1 <= num_2)
print(num_1 >= num_2)
# Out:
# 1
# 4
# 3.9
# False
# True
# True
# False
# True
# False

# %%
num_1 = '100'
num_2 = '300'

print(num_1+num_2)

num_1 = int(num_1)
num_2 = int(num_2)

print(num_1+num_2)
# Out:
# 100300
# 400

# %%
courses = ['maths', 'histroy', 'comp', 'sci'] #creating a list

print(len(courses))
print(courses[0])
print(courses[3])
print(courses[-1])

print(courses[0:2]) # slicing

courses = ['maths', 'histroy', 'comp', 'sci']

courses.insert(0, 'art') # append add art to the end where as if we put insert and provide value it shows at first postion

print(courses)

courses = ['maths', 'histroy', 'comp', 'sci']
 # txtend the list

courses_2 = ['Art', 'Education']
courses.insert(0, courses)
courses.extend(courses_2)

print(courses)

courses = ['maths', 'histroy', 'comp', 'sci']

courses.remove('maths')

print(courses)

courses = ['maths', 'histroy', 'comp', 'sci'] # pop option

poppped = courses.pop()
courses.reverse()

print(popped)
print(courses)

courses = ['maths', 'histroy', 'comp', 'sci'] # reverse the element 

courses.reverse()

print(courses)



courses = ['maths', 'histroy', 'comp', 'sci'] # sortung of list

num = [1, 2, 3, 4, 6]

courses.sort()
num.sort()
 
print(courses)
print(nums) # sorting the numbers in ascending order

courses = ['maths', 'histroy', 'comp', 'sci'] # soring of list

num = [1, 2, 3, 4, 6]

courses.sort(reverse=True)
num.sort(reverse=True)
 
print(courses)
print(nums) # sorting the data in decending data

courses = ['maths', 'histroy', 'comp', 'sci'] # soring of  the data without altering the original one 

num = [1, 2, 3, 4, 6]


sorted_courses = sorted(courses)
 
print(sorted_courses)

print(sum(nums))
print(min(nums))
print(max(nums))

courses = ['maths', 'histroy', 'comp', 'sci'] #

print(courses.index('sci'))
print('art' in courses)
print('maths' in courses)

for item in courses: #if we place course at the place of item same result
    print(item)

for index, courses in enumerate(courses, start=1):
    print(index, courses)
# Out:
# 4
# maths
# sci
# sci
# ['maths', 'histroy']
# ['art', 'maths', 'histroy', 'comp', 'sci']
# [[...], 'maths', 'histroy', 'comp', 'sci', 'Art', 'Education']
# ['histroy', 'comp', 'sci']
# comp
# ['comp', 'histroy', 'maths']
# ['sci', 'comp', 'histroy', 'maths']
# ['comp', 'histroy', 'maths', 'sci']
# [1, 4, 6, 7]
# ['sci', 'maths', 'histroy', 'comp']
# [1, 4, 6, 7]
# ['comp', 'histroy', 'maths', 'sci']
# 18
# 1
# 7
# 3
# False
# True
# maths
# histroy
# comp
# sci
# 1 maths
# 2 histroy
# 3 comp
# 4 sci

# %%
# testing len()
str1 = "you looK pretty"
print("the length of the string is :", len(str1))
# Out:
# the length of the string is : 15

# %%
age = [5,19,25,23,45]
x= [15,19,25,23,45]
def myfunc(x):
  if x > 15:
    return false
  else:
    return true

adults = filter(myfunc(x), ages(25))

for x in adults:
  print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a073ba61c9df> in <module>()
#       7     return true
#       8
# ----> 9 adults = filter(myfunc(x), ages(25))
#      10
#      11 for x in adults:
#
# <ipython-input-33-a073ba61c9df> in myfunc(x)
#       2 x= [15,19,25,23,45]
#       3 def myfunc(x):
# ----> 4   if x > 15:
#       5     return false
#       6   else:
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path ="/content/drive/MyDrive/python/bank.csv.txt"
df = pd.read_csv(path)

# data is stored as pandas dataframe

df.describe
# Out:
# <bound method NDFrame.describe of        age          job  marital  education  ... pdays  previous poutcome deposit
# 0       59       admin.  married  secondary  ...    -1         0  unknown     yes
# 1       56       admin.  married  secondary  ...    -1         0  unknown     yes
# 2       41   technician  married  secondary  ...    -1         0  unknown     yes
# 3       55     services  married  secondary  ...    -1         0  unknown     yes
# 4       54       admin.  married   tertiary  ...    -1         0  unknown     yes
# ...    ...          ...      ...        ...  ...   ...       ...      ...     ...
# 11157   33  blue-collar   single    primary  ...    -1         0  unknown      no
# 11158   39     services  married  secondary  ...    -1         0  unknown      no
# 11159   32   technician   single  secondary  ...    -1         0  unknown      no
# 11160   43   technician  married  secondary  ...   172         5  failure      no
# ...
